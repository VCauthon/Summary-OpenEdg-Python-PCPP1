# %% [markdown]
# # Abstract Classes
#
# ---

# %% [markdown]
# ### Let's code an example
#
# In Python it is necessary to use the ABC class (Abstract Base Classes) to generate an abstract class.
#
# This creation is generated by inheriting from ABC and creating decorated methods with @abstractmethod (both modules come from abc).
#
# Let's try to create, from the previous image, the class Dog and LabradorRetriever.
#
# ![Alt text](<abstract class.png>)

# %%
from abc import ABC, abstractmethod


class Dog(ABC):
    def __init__(self, name) -> None:
        self.name = name

    @abstractmethod
    def bark():
        pass

    @abstractmethod
    def eat():
        pass

class LabradorRetriever(Dog):

    def bark(self):
        print(f"{self.name}: Hi fellow human!")

    def eat(self):
        print(f"{self.name}: If you don't mind, I'm going to eat")

dog_1 = LabradorRetriever("Max")
dog_1.bark()
dog_1.eat()
# Out:
# Max: Hi fellow human!
# Max: If you don't mind, I'm going to eat

# %% [markdown]
# ---

# %% [markdown]
# ### Raising errors
#
# What happens if we try to implement the GermanShepherd class?
#
# Basically... it will raise an error because it misses one abstract method.

# %%
from abc import ABC, abstractmethod


class Dog(ABC):
    def __init__(self, name) -> None:
        self.name = name

    @abstractmethod
    def bark():
        pass

    @abstractmethod
    def eat():
        pass

class LabradorRetriever(Dog):

    def bark(self):
        print(f"{self.name}: Hello fellow human!")

    def eat(self):
        print(f"{self.name}: If you don't mind, I'm going to eat")

class GermanShepherd(Dog):

    def bark(self):
        print(f"{self.name}: Hallo Mitmensch!")

dog_1 = LabradorRetriever("Max")
dog_1.bark()
dog_1.eat()

dog_2 = GermanShepherd("Rex")
dog_2.bark()
# Out:
# Max: Hello fellow human!
# Max: If you don't mind, I'm going to eat
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/vcauthon/Workspace/Summary-OpenEdg-Pyhon-PCPP1/1.Advanced-OOP/2.OOP-Advanced/6.Abstract-classes/Material.ipynb Cell 6 line 3
#      <a href='vscode-notebook-cell:/home/vcauthon/Workspace/Summary-OpenEdg-Pyhon-PCPP1/1.Advanced-OOP/2.OOP-Advanced/6.Abstract-classes/Material.ipynb#X10sZmlsZQ%3D%3D?line=29'>30</a> dog_1.bark()
#      <a href='vscode-notebook-cell:/home/vcauthon/Workspace/Summary-OpenEdg-Pyhon-PCPP1/1.Advanced-OOP/2.OOP-Advanced/6.Abstract-classes/Material.ipynb#X10sZmlsZQ%3D%3D?line=30'>31</a> dog_1.eat()
# ---> <a href='vscode-notebook-cell:/home/vcauthon/Workspace/Summary-OpenEdg-Pyhon-PCPP1/1.Advanced-OOP/2.OOP-Advanced/6.Abstract-classes/Material.ipynb#X10sZmlsZQ%3D%3D?line=32'>33</a> dog_2 = GermanShepherd("Rex")
#      <a href='vscode-notebook-cell:/home/vcauthon/Workspace/Summary-OpenEdg-Pyhon-PCPP1/1.Advanced-OOP/2.OOP-Advanced/6.Abstract-classes/Material.ipynb#X10sZmlsZQ%3D%3D?line=33'>34</a> dog_2.bark()
#
# TypeError: Can't instantiate abstract class GermanShepherd with abstract method eat

# %% [markdown]
# The same will happen if we instantiate the Dog class.

# %%
from abc import ABC, abstractmethod


class Dog(ABC):
    def __init__(self, name) -> None:
        self.name = name

    @abstractmethod
    def bark():
        pass

    @abstractmethod
    def eat():
        pass

dog_1 = Dog("Max")
dog_1.bark()
dog_1.eat()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/vcauthon/Workspace/Summary-OpenEdg-Pyhon-PCPP1/1.Advanced-OOP/2.OOP-Advanced/6.Abstract-classes/Material.ipynb Cell 8 line 1
#      <a href='vscode-notebook-cell:/home/vcauthon/Workspace/Summary-OpenEdg-Pyhon-PCPP1/1.Advanced-OOP/2.OOP-Advanced/6.Abstract-classes/Material.ipynb#X13sZmlsZQ%3D%3D?line=11'>12</a>     @abstractmethod
#      <a href='vscode-notebook-cell:/home/vcauthon/Workspace/Summary-OpenEdg-Pyhon-PCPP1/1.Advanced-OOP/2.OOP-Advanced/6.Abstract-classes/Material.ipynb#X13sZmlsZQ%3D%3D?line=12'>13</a>     def eat():
#      <a href='vscode-notebook-cell:/home/vcauthon/Workspace/Summary-OpenEdg-Pyhon-PCPP1/1.Advanced-OOP/2.OOP-Advanced/6.Abstract-classes/Material.ipynb#X13sZmlsZQ%3D%3D?line=13'>14</a>         pass
# ---> <a href='vscode-notebook-cell:/home/vcauthon/Workspace/Summary-OpenEdg-Pyhon-PCPP1/1.Advanced-OOP/2.OOP-Advanced/6.Abstract-classes/Material.ipynb#X13sZmlsZQ%3D%3D?line=15'>16</a> dog_1 = Dog("Max")
#      <a href='vscode-notebook-cell:/home/vcauthon/Workspace/Summary-OpenEdg-Pyhon-PCPP1/1.Advanced-OOP/2.OOP-Advanced/6.Abstract-classes/Material.ipynb#X13sZmlsZQ%3D%3D?line=16'>17</a> dog_1.bark()
#      <a href='vscode-notebook-cell:/home/vcauthon/Workspace/Summary-OpenEdg-Pyhon-PCPP1/1.Advanced-OOP/2.OOP-Advanced/6.Abstract-classes/Material.ipynb#X13sZmlsZQ%3D%3D?line=17'>18</a> dog_1.eat()
#
# TypeError: Can't instantiate abstract class Dog with abstract methods bark, eat

# %% [markdown]
# ---
